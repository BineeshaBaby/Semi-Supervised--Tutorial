# %%
# Initialize Label Propagation model
label_prop = LabelPropagation()
label_prop.fit(X, y)

# Predict labels for all data
y_pred = label_prop.transduction_

# Visualize the results
plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap='viridis', s=50)
plt.title("Label Propagation Results")
plt.show()

# %% [markdown]
# apply label propagation

# %%
from sklearn.semi_supervised import LabelPropagation
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
import numpy as np

# Generate synthetic data
X, y = make_moons(n_samples=200, noise=0.1, random_state=42)

# Mask some labels as unlabeled (-1)
rng = np.random.RandomState(42)
y[rng.rand(len(y)) > 0.7] = -1

# %% [markdown]
# # Label Propagation with Semi-Supervised Learning
# This notebook demonstrates label propagation using graph-based techniques.
